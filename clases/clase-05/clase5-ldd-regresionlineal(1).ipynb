# %% [markdown]
# # Regresión Lineal
#
# ### Laboratorio de Datos, IC - FCEN - UBA - 1er. Cuatrimestre 2024

# %% [markdown]
# ### Nuevas librerías
#
# Utilizaremos el módulo `scikit-learn` y `formulaic` de Python. Para instalarlos, correr:

# %%
# !pip install scikit-learn
# !pip install formulaic
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from scikit-learn) (2.4.4)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 28.8 MB/s  0:00:00 eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 59.2 MB/s  0:00:00 eta 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# Collecting formulaic
#   Downloading formulaic-1.2.1-py3-none-any.whl.metadata (7.0 kB)
# Collecting interface-meta>=1.2.0 (from formulaic)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting narwhals>=1.17 (from formulaic)
#   Downloading narwhals-2.19.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.20.0 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from formulaic) (2.4.4)
# Requirement already satisfied: pandas>=1.3 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from formulaic) (3.0.2)
# Requirement already satisfied: scipy>=1.6 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from formulaic) (1.17.1)
# Collecting typing-extensions>=4.2.0 (from formulaic)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.17.0rc1 (from formulaic)
#   Downloading wrapt-2.2.0rc7-cp314-cp314-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from pandas>=1.3->formulaic) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->formulaic) (1.17.0)
# Downloading formulaic-1.2.1-py3-none-any.whl (117 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading narwhals-2.19.0-py3-none-any.whl (446 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wrapt-2.2.0rc7-cp314-cp314-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (158 kB)
# Installing collected packages: wrapt, typing-extensions, narwhals, interface-meta, formulaic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [formulaic]/5 [narwhals]
# Successfully installed formulaic-1.2.1 interface-meta-1.3.0 narwhals-2.19.0 typing-extensions-4.15.0 wrapt-2.2.0rc7

# %% [markdown]
# Importamos los módulos de siempre, las herramientas de modelos lineales y las medidas de desempeño del modelo de `scikit-learn`:

# %%
# !pip install seaborn 
# !pip install seaborn.objects
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.1)
# Requirement already satisfied: pillow>=8 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/luca/_labodatos/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# ERROR: Could not find a version that satisfies the requirement seaborn.objects (from versions: none)
# ERROR: No matching distribution found for seaborn.objects

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn.objects as so

# Para plantear el modelo lineal
from formulaic import Formula   

# Herramientas de modelos lineales
from sklearn import linear_model  

# Medidas de desempeño
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# %% [markdown]
# ### Modelo de Regresión Lineal
#
# Queremos utilizar un modelo lineal:
# $$ Y = \beta_0 + \beta_1 X $$
# para intentar predecir valores continuos.

# %% [markdown]
# ### Visualización
#
# Con lo que hemos visto las clases anteriores, visualizar la recta que mejor aproxima a los datos en el sentido de cuadrados mínimos es relativamente sencillo con `seaborn objects`, ya que `seaborn` calcula automáticamente los valores de $\beta_0$ y $\beta_1$.
#
# Utilizaremos el dataset _tips_ de `seaborn` y analizaremos la relación entre lo que costó la comida y la cantidad de propina.

# %%
datos = sns.load_dataset('tips')

# %% [markdown]
# Visualizamos los datos con `so.Plot` (repasar clase de visualización)

# %%
datos
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Graficamos la relacion entre las variables 

(
    so.Plot(data=datos, x='total_bill', y='tip')
    .add(so.Dot())
)

# %% [markdown]
# Para visualizar la recta de la regresión, agregamos una línea al gráfico (`so.Line()`) junto a `so.PolyFit(1)`:

# %%
(
    so.Plot(data=datos, x='total_bill', y='tip')
    .add(so.Dot(),label= 'Propinas')
    .add(so.Line(color='red', linewidth=3), so.PolyFit(1), label='Regresion lineal')    # Agregamos una etiqueta para la leyenda del grafico
    .label(title='Datos de propinas', x='Precio de la comida', y='Propina')    # Agregamos la leyenda, un titulo y le cambiamos el nombre a los ejes
)

# %% [markdown]
# ### Cálculo de coeficientes y predicciones
#
# Desafortunamente, `seaborn` no nos devuelve los valores de $\beta_0$ y $\beta_1$, que son importantes en la interpretación del resultado.
#
# Hemos visto que podemos calcular los coeficientes de la regresión lineal como:
#
#  $$
#  \begin{array}{rl}
#       \hat{\beta}_1 = & \dfrac{\displaystyle\sum_{i=1}^n(x_i - \bar{x})(y_i - \bar{y})}{\displaystyle\sum_{i=1}^n(x_i - \bar{x})^2}  \\[1em]
#       \hat{\beta}_0 = & \bar{y} - \hat{\beta}_1\bar{x}
#  \end{array}
#  $$
#
#  pero también podemos utilizar `scikit-learn` y `formulaic`. Como ejercicio en la práctica también se pueden calcular a manopla con numpy

# %% [markdown]
# Como queremos predecir la propina según el precio de la comida usando una función lineal, la fórmula de Wilkinson es:
# $$tip \sim total\_bill$$

# %% [markdown]
# La matriz  y =[propina1,propina2,propina3, etc] es una matriz columna de propinas.
# La matriz X es una matriz con una columna de 1 y con los factores que van a multiplicar a beta_1

# %%
# Obtenemos las matrices del modelo
y, X = Formula('tip ~ total_bill').get_model_matrix(datos)

# %%
y
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %%
X
# Out:
#      Intercept  total_bill
# 0          1.0       16.99
# 1          1.0       10.34
# 2          1.0       21.01
# 3          1.0       23.68
# 4          1.0       24.59
# ..         ...         ...
# 239        1.0       29.03
# 240        1.0       27.18
# 241        1.0       22.67
# 242        1.0       17.82
# 243        1.0       18.78
#
# [244 rows x 2 columns]

# %%
# Inicializamos el modelo de regresión.
modelo = linear_model.LinearRegression(fit_intercept=False) # RECORDAR USAR fit_intercept = False

# Realiza el ajuste
modelo.fit(X, y)

# Para obtener los valores de beta_1 y beta_0 como valores numericos
beta = modelo.coef_
beta
# Out:
# array([[0.92026961, 0.10502452]])

# %%
beta_0 = beta[0][0]
beta_1 = beta[0][1]
print('Beta_0: ', beta_0)
print('Beta_1: ', beta_1)
# Out:
# Beta_0:  0.9202696135546726
# Beta_1:  0.10502451738435345

# %% [markdown]
# Entonces, la recta que mejor aproxima a los datos es (redondeando):
# $$ Y = 0.92 + 0.105 X$$

# %% [markdown]
# Una interpretación que podemos darle a este resultado es que, por cada peso que costó la comida, se dejan de propina 0.105 pesos (o sea, alrededor de 10 centavos)
#
# Con los valores de $\beta_0$ y $\beta_1$ podemos predecir cuanto será la propina según el valor de la comida. Supongamos que queremos predecir la propina que se deja por una cuenta \\$35. Utilizamos el método `predict()` del modelo.
#
# <span style="color:red">**EL MÉTODO .predict() SOLO ADMITE ADMITE DATAFRAMES (O MATRICES).**</span>

# %%
# Creamos un array con los valores a predecir
x_a_predecir = np.array([35])

# Creamos un DataFrame con los valores de X para los que queremos predecir
# Debe tener una columna de 1's que sea el Intercept (término independiente).
# Los nombres de las columnas deben coincidir con aquellos usados en el fit.
dataframe_a_predecir = pd.DataFrame({'Intercept': np.ones(x_a_predecir.shape), 'total_bill': x_a_predecir})

# Aplicamos la fórmula del modelo
modelo.predict(dataframe_a_predecir)
# Out:
# array([[4.59612772]])

# %%
dataframe_a_predecir
# Out:
#    Intercept  total_bill
# 0        1.0          35

# %%
# Para devolver directamente el numero agregamos .item()
modelo.predict(dataframe_a_predecir).item()
# Out:
# 4.596127722007044

# %% [markdown]
# También podemos hacer directamente la cuenta porque ya sabemos cuanto valen $\beta_1$ y $\beta_0$:

# %%
beta_1 * 35 + beta_0
# Out:
# np.float64(4.596127722007044)

# %% [markdown]
# Podemos predecir varios valores de una:

# %%
# Creamos un array con los valores a predecir
x_a_predecir = np.array([35, 60])

# Creamos un DataFrame con los valores de X para los que queremos predecir
# Debe tener una columna de 1's que sea el Intercept (término independiente)
dataframe_a_predecir = pd.DataFrame({'Intercept': np.ones(x_a_predecir.shape), 'total_bill': x_a_predecir})

# Aplicamos la fórmula del modelo
modelo.predict(dataframe_a_predecir)
# Out:
# array([[4.59612772],
#        [7.22174066]])

# %% [markdown]
# Si queremos calcular los valores predichos por el modelo $\hat{y}_i$ para todos nuestros $x_i$:

# %%
y_pred = modelo.predict(X)
display(y_pred)
# Out:
# array([[2.70463616],
#        [2.00622312],
#        [3.12683472],
#        [3.40725019],
#        [3.5028225 ],
#        [3.57633966],
#        [1.84133463],
#        [3.74332864],
#        [2.49983836],
#        [2.47253198],
#        [1.99887141],
#        [4.6234341 ],
#        [2.53974767],
#        [2.85587147],
#        [2.47778321],
#        [3.1866987 ],
#        [2.00517288],
#        [2.631119  ],
#        [2.70253567],
#        [3.0890259 ],
#        [2.80230897],
#        [3.05121707],
#        [2.57650625],
#        [5.06033609],
#        [3.00185555],
#        [2.79075627],
#        [2.32444741],
#        [2.25303074],
#        [3.19930164],
#        [2.98400138],
#        [1.92325375],
#        [2.84746951],
#        [2.50193885],
#        [3.09322688],
#        [2.78760553],
#        [3.4471595 ],
#        [2.63321949],
#        [2.69833469],
#        [2.88317784],
#        [4.20438627],
#        [2.60486287],
#        [2.75399769],
#        [2.38431139],
#        [1.93690694],
#        [4.11301494],
#        [2.84116804],
#        [3.25496464],
#        [4.32306398],
#        [3.91871958],
#        [2.81491191],
#        [2.23727706],
#        [2.0009719 ],
#        [4.57617306],
#        [1.96421332],
#        [3.60469628],
#        [2.96719746],
#        [4.91225152],
#        [3.69396712],
#        [2.10074519],
#        [5.98980307],
#        [3.05121707],
#        [2.3706582 ],
#        [2.0776398 ],
#        [2.84116804],
#        [2.76765087],
#        [3.02916192],
#        [2.64792292],
#        [1.24269488],
#        [3.0449156 ],
#        [2.49668762],
#        [2.18266431],
#        [2.71303813],
#        [3.74122815],
#        [3.57528941],
#        [2.46728075],
#        [2.02407729],
#        [2.80230897],
#        [3.77693649],
#        [3.31062763],
#        [2.73614352],
#        [2.96194623],
#        [2.66997807],
#        [1.9778665 ],
#        [4.35247084],
#        [2.5985614 ],
#        [4.57827355],
#        [2.28873908],
#        [2.84011779],
#        [3.51542544],
#        [3.1425884 ],
#        [3.96282988],
#        [3.28227101],
#        [1.52416059],
#        [2.63426974],
#        [3.30957738],
#        [5.13910448],
#        [3.78533845],
#        [2.18371456],
#        [3.12683472],
#        [2.2288751 ],
#        [2.11229789],
#        [2.53554669],
#        [5.57285573],
#        [3.27491929],
#        [3.11738252],
#        [2.5334462 ],
#        [3.07222197],
#        [3.5679377 ],
#        [2.83591681],
#        [2.42317046],
#        [2.39061286],
#        [1.68169736],
#        [4.91855299],
#        [3.4356068 ],
#        [3.62044996],
#        [2.73824401],
#        [4.06365342],
#        [2.03878072],
#        [2.22572436],
#        [3.44925999],
#        [2.14800622],
#        [2.32969864],
#        [2.41791923],
#        [2.59541067],
#        [2.23097559],
#        [4.05000023],
#        [1.8150785 ],
#        [2.44522561],
#        [2.11544862],
#        [3.3169291 ],
#        [2.92413741],
#        [3.04911658],
#        [2.09339347],
#        [2.2078702 ],
#        [2.8380173 ],
#        [1.81402826],
#        [2.00517288],
#        [2.40636653],
#        [2.60066189],
#        [2.30239226],
#        [2.75504793],
#        [4.52261056],
#        [5.24622948],
#        [3.76118281],
#        [2.64582243],
#        [1.79722433],
#        [2.87792662],
#        [2.16691063],
#        [1.94740939],
#        [1.70900374],
#        [2.39796457],
#        [2.29924153],
#        [2.73299278],
#        [3.49862152],
#        [2.99660432],
#        [4.05525146],
#        [5.97930062],
#        [3.54588255],
#        [2.3265479 ],
#        [2.65212391],
#        [3.17829674],
#        [2.24988   ],
#        [2.62271704],
#        [2.3706582 ],
#        [2.75924891],
#        [3.49547078],
#        [3.10057859],
#        [4.25059706],
#        [2.03247925],
#        [2.03668023],
#        [6.25656534],
#        [2.58070723],
#        [1.68169736],
#        [4.26530049],
#        [2.686782  ],
#        [4.37557624],
#        [2.79915823],
#        [2.44102463],
#        [1.92850498],
#        [4.55726865],
#        [4.55936914],
#        [3.3704916 ],
#        [5.68313148],
#        [3.35368768],
#        [5.17901379],
#        [3.09322688],
#        [3.11528203],
#        [4.11931641],
#        [2.8264646 ],
#        [3.34633597],
#        [2.56810429],
#        [3.0008053 ],
#        [3.90716689],
#        [2.54604914],
#        [2.66157611],
#        [1.71425496],
#        [2.00622312],
#        [5.44787656],
#        [2.28558834],
#        [2.33915084],
#        [2.88527833],
#        [2.25828197],
#        [2.28558834],
#        [2.6426717 ],
#        [3.07642296],
#        [2.65002341],
#        [3.71287153],
#        [4.98786917],
#        [3.46921465],
#        [2.26038246],
#        [4.07730661],
#        [3.63935437],
#        [5.99610454],
#        [2.31394496],
#        [3.87881027],
#        [2.27508589],
#        [3.87670978],
#        [2.13750377],
#        [1.73315938],
#        [4.08570857],
#        [2.19736774],
#        [2.32969864],
#        [1.82137997],
#        [2.5985614 ],
#        [2.32969864],
#        [2.62901851],
#        [1.97996699],
#        [3.06802099],
#        [2.3149952 ],
#        [3.24341194],
#        [3.44190828],
#        [2.56810429],
#        [2.13960426],
#        [2.05138367],
#        [2.55130037],
#        [1.9778665 ],
#        [2.24357853],
#        [4.36822452],
#        [4.68329807],
#        [3.96913135],
#        [3.774836  ],
#        [3.30117542],
#        [2.79180651],
#        [2.89263005]])

# %% [markdown]
# #### Ejercicio

# %% [markdown]
# Utilizando el ya calculado `y_pred`, comparar en un mismo gráfico la recta de regresión obtenida con `seaborn objects` (en rojo y etiquetada "Regresion Seaborn") y la que resulta de utilizar `scikit-learn` (en azul y etiqueatada "Regresion Scikit"). El eje `y` debe tener la etiqueta "propina", el eje `x` la etiqueta "precio de la comida".

# %%
(
    so.Plot(data=datos, x='total_bill', y='tip')
    .add(so.Dot(), label='Propinas')
    .add(so.Line(color='red', linewidth=3), so.PolyFit(1), label='Regresion lineal')
    .add(so.Line(color='green', linewidth=3), y=pd.Series(y_pred.ravel(), index=datos.index), label='Regresion Scikit')
    .label(title='Datos de propinas', x='Precio de la comida', y='Propina')
)

# %% [markdown]
# ### ¿Qué tan bueno es el modelo?

# %% [markdown]
# Finalmente, el bueno de `scikit-learn` nos calcula el coeficiente de determinación $R^ 2$: primero van los datos observados ( $y$ ) y luego los datos predichos ( $\hat{y}$ )

# %%
y_pred = modelo.predict(X)
r2_score(datos['tip'], y_pred)
# Out:
# 0.45661658635167646

# %% [markdown]
# De manera análoga podemos calcular el error cuadrático medio (ECM):

# %%
mean_squared_error(datos['tip'], y_pred)
# Out:
# 1.036019442011377

# %% [markdown]
# Y la raíz del error cuadrático medio:

# %%
root_mean_squared_error(datos['tip'], y_pred)
# Out:
# 1.0178504025697377

# %% [markdown]
# Esto último podría interpretarse (informalmente) como que al usar el modelo para predecir cuánta propina dejo, en
# promedio voy a cometer un error en el margen de $\pm 1.01785$ pesos.
